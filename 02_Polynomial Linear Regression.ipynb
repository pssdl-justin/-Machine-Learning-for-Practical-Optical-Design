# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:2].values
y = dataset.iloc[:, 2].values

print(X.shape)
# Out:
# (10, 1)

# %% [markdown]
# # Fitting Linear Regression to the dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %%
# Visualising the Linear Regression Results
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.title('Truth or Bluff (Linear Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %%
print("reg1 coef=", lin_reg.coef_)
print("reg1 intercept=", lin_reg.intercept_)
print('score = %.4f' %lin_reg.score(X, y))

R2_1 = lin_reg.score(X, y)
AR2_1 = 1 - (1 - R2_1) * (len(y) - 1) / (len(y) - X.shape[1] - 1)
print(R2_1, AR2_1)
# Out:
# reg1 coef= [80878.78787879]
# reg1 intercept= -195333.33333333337
# score = 0.6690
# 0.6690412331929895 0.6276713873421131

# %% [markdown]
# # Fitting Polynomial Regression to the dataset order=2

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg_2 = PolynomialFeatures(degree = 2)
X_poly_2 = poly_reg_2.fit_transform(X)
print(X_poly_2.shape)

lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly_2, y)

print('score = %.4f' %lin_reg_2.score(X_poly_2, y))


R2_2 = lin_reg_2.score(X_poly_2, y)
AR2_2 = 1 - (1 - R2_2) * (len(y) - 1) / (len(y) - X_poly_2.shape[1] - 2)
print(R2_2, AR2_2)
# Out:
# (10, 3)
# score = 0.9162
# 0.9162082221443942 0.8491747998599096

# %%
# Visualising the Polynomial Regression Results
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_2.predict(X_poly_2), color = 'blue')
plt.title('Truth or Bluff (Polynomal Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # Fitting Polynomial Regression to the dataset order=3

# %%
poly_reg_3 = PolynomialFeatures(degree = 3)
X_poly_3 = poly_reg_3.fit_transform(X)
lin_reg_3 = LinearRegression()
lin_reg_3.fit(X_poly_3, y)

print('score = %.4f' %lin_reg_3.score(X_poly_3, y))

R2_3 = lin_reg_3.score(X_poly_3, y)
AR2_3 = 1 - (1 - R2_3) * (len(y) - 1) / (len(y) - X_poly_3.shape[1] - 2)
print(R2_3, AR2_3)
# Out:
# score = 0.9812
# 0.9812097727913367 0.9577219887805075

# %%
# Visualising the Polynomial Regression Results
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg_3.predict(X_poly_3), color = 'blue')
plt.title('Truth or Bluff (Polynomal Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # Fitting Polynomial Regression to the dataset order=4

# %%
poly_reg_4 = PolynomialFeatures(degree = 4)
X_poly_4 = poly_reg_4.fit_transform(X)
lin_reg_4 = LinearRegression()
lin_reg_4.fit(X_poly_4, y)

print("reg1 coef=", lin_reg_4.coef_)
print("reg1 intercept=", lin_reg_4.intercept_)
print('score=%.4f' % lin_reg_4.score(X_poly_4, y))

R2_4 = lin_reg_4.score(X_poly_4, y)
AR2_4 = 1 - (1 - R2_4) * (len(y) - 1) / (len(y) - X_poly_4.shape[1] - 2)
print(R2_4, AR2_4)
# Out:
# reg1 coef= [      0.         -211002.33100292   94765.44289063  -15463.28671331
#      890.15151515]
# reg1 intercept= 184166.66666719737
# score=0.9974
# 0.9973922891706615 0.9921768675119844

# %%
# Visualising the Polynomial Regression Results
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape(len(X_grid), 1)
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, lin_reg_4.predict(poly_reg_4.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomal Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # Fitting Polynomial Regression to the dataset order=5

# %%
poly_reg_5 = PolynomialFeatures(degree = 5)
X_poly_5 = poly_reg_5.fit_transform(X)
lin_reg_5 = LinearRegression()
lin_reg_5.fit(X_poly_5, y)

print("reg1 coef=", lin_reg_5.coef_)
print("reg1 intercept=", lin_reg_5.intercept_)
print('score=%.4f' % lin_reg_5.score(X_poly_5, y))

R2_5 = lin_reg_5.score(X_poly_5, y)
AR2_5 = 1 - (1 - R2_5) * (len(y) - 1) / (len(y) - X_poly_5.shape[1] - 2)
print(R2_5, AR2_5)
# Out:
# reg1 coef= [ 0.00000000e+00  1.60731002e+05 -1.00378788e+05  2.81649184e+04
#  -3.44638695e+03  1.57692308e+02]
# reg1 intercept= -41333.33332994394
# score=0.9998
# 0.9997969027099755 0.9990860621948896

# %%
poly_reg_6 = PolynomialFeatures(degree = 6)
X_poly_6 = poly_reg_6.fit_transform(X)
lin_reg_6 = LinearRegression()
lin_reg_6.fit(X_poly_6, y)

print("reg1 coef=", lin_reg_6.coef_)
print("reg1 intercept=", lin_reg_6.intercept_)
print('score=%.4f' % lin_reg_6.score(X_poly_6, y))

R2_6 = lin_reg_6.score(X_poly_6, y)
AR2_6 = 1 - (1 - R2_6) * (len(y) - 1) / (len(y) - X_poly_6.shape[1] - 2)
print(R2_6, AR2_6)
# Out:
# reg1 coef= [ 0.00000000e+00 -8.29439977e+04  6.58964015e+04 -2.43819566e+04
#   4.92908654e+03 -4.95432692e+02  1.97916667e+01]
# reg1 intercept= 82166.66665970627
# score=0.9999
# 0.9999494749253776 0.999545274328398

# %%
plt.scatter(np.linspace(1, 6, 6), [R2_1, R2_2, R2_3, R2_4, R2_5, R2_6], color = 'blue')
plt.scatter(np.linspace(1, 6, 6), [AR2_1, AR2_2, AR2_3, AR2_4, AR2_5, AR2_6], color = 'red')
